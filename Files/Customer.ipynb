# %%
import pandas as pd

# %%
df= pd.read_csv('/home/harshit/csv files/Telco-Customer-Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df['TotalCharges']
# Out:
# 0         29.85
# 1       1889.50
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038    1990.50
# 7039    7362.90
# 7040     346.45
# 7041     306.60
# 7042    6844.50
# Name: TotalCharges, Length: 7043, dtype: float64

# %%
df.shape
# Out:
# (7043, 21)

# %%
X= df.drop(['Churn', 'customerID'], axis=1)
y= df['Churn']

# %%
X_cat= X.select_dtypes(include=['object'])
X_num= X.select_dtypes(exclude=['object'])

# %%
X_cat
# Out:
#       gender Partner Dependents PhoneService     MultipleLines  \
# 0     Female     Yes         No           No  No phone service
# 1       Male      No         No          Yes                No
# 2       Male      No         No          Yes                No
# 3       Male      No         No           No  No phone service
# 4     Female      No         No          Yes                No
# ...      ...     ...        ...          ...               ...
# 7038    Male     Yes        Yes          Yes               Yes
# 7039  Female     Yes        Yes          Yes               Yes
# 7040  Female     Yes        Yes           No  No phone service
# 7041    Male     Yes         No          Yes               Yes
# 7042    Male      No         No          Yes                No
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No          No
# ...

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
ohe = OneHotEncoder(sparse_output=False, handle_unknown='ignore', dtype='int')
le= LabelEncoder()

# %%
ohe_features=X_cat[['MultipleLines', 'InternetService', 'Contract', 'PaymentMethod']]
ohe.fit(ohe_features)
ohe_features_names=ohe.get_feature_names_out(ohe_features.columns)

# %%
label_feateres=X_cat.drop(['MultipleLines', 'InternetService',  'Contract', 'PaymentMethod'], axis=1)

# %%
for i in label_feateres:
    X_cat[i]=le.fit_transform(label_feateres[i])
X_cat['StreamingMovies']=le.fit_transform(X_cat['StreamingMovies'])

# %%
X_cat
# Out:
#       gender  Partner  Dependents  PhoneService     MultipleLines  \
# 0          0        1           0             0  No phone service
# 1          1        0           0             1                No
# 2          1        0           0             1                No
# 3          1        0           0             0  No phone service
# 4          0        0           0             1                No
# ...      ...      ...         ...           ...               ...
# 7038       1        1           1             1               Yes
# 7039       0        1           1             1               Yes
# 7040       0        1           1             0  No phone service
# 7041       1        1           0             1               Yes
# 7042       1        0           0             1                No
#
#      InternetService  OnlineSecurity  OnlineBackup  DeviceProtection  \
# 0                DSL               0             2                 0
# ...

# %%
ohe_df=pd.DataFrame(ohe.transform(ohe_features), columns=ohe_features_names)
X_cat=X_cat.drop(['MultipleLines', 'InternetService',  'Contract', 'PaymentMethod'], axis=1)
X_cat=pd.concat([X_cat, ohe_df], axis=1)
X_cat
# Out:
#       gender  Partner  Dependents  PhoneService  OnlineSecurity  OnlineBackup  \
# 0          0        1           0             0               0             2
# 1          1        0           0             1               2             0
# 2          1        0           0             1               2             2
# 3          1        0           0             0               2             0
# 4          0        0           0             1               0             0
# ...      ...      ...         ...           ...             ...           ...
# 7038       1        1           1             1               2             0
# 7039       0        1           1             1               0             2
# 7040       0        1           1             0               2             0
# 7041       1        1           0             1               0             0
# 7042       1        0           0             1               2             0
#
# ...

# %%
X_final= pd.concat([X_num, X_cat], axis=1)
X_final['TotalCharges']=X_final['TotalCharges'].fillna(0)
X_final.isnull().sum()
# Out:
# SeniorCitizen                              0
# tenure                                     0
# MonthlyCharges                             0
# TotalCharges                               0
# gender                                     0
# Partner                                    0
# Dependents                                 0
# PhoneService                               0
# OnlineSecurity                             0
# OnlineBackup                               0
# DeviceProtection                           0
# TechSupport                                0
# StreamingTV                                0
# StreamingMovies                            0
# PaperlessBilling                           0
# MultipleLines_No                           0
# MultipleLines_No phone service             0
# MultipleLines_Yes                          0
# InternetService_DSL                        0
# InternetService_Fiber optic                0
# InternetService_No                         0
# ...

# %%
y=le.fit_transform(y)
y
# Out:
# array([0, 0, 1, ..., 0, 1, 0], shape=(7043,))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_final, y, test_size=0.2, random_state=42, stratify=y)

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV, cross_validate

# %%
models={
    'rf': RandomForestClassifier(),
    'gbc': GradientBoostingClassifier(),
    'hgbc': HistGradientBoostingClassifier()
    
}
params={
    'rf': {'n_estimators': [100, 200,250], 'max_depth': [None, 10, 20],'min_samples_leaf': [2, 5, 10]},
    'gbc': {'n_estimators': [100,200,250], 'learning_rate': [ 0.1,0.2,0.5,0.8],'min_samples_leaf': [2, 5, 10]},
    'hgbc': {'max_iter': [100, 200,250], 'max_depth': [None, 10],'min_samples_leaf': [2, 5, 10]}
}

# %%
for model,value in models.items():
    classifier=RandomizedSearchCV(models[model],params[model], cv=5, n_iter=10)
    classifier.fit(X_train, y_train)
    print(f'Best parameters for {model}: {classifier.best_params_}')
    print(f'Best score for {model}: {classifier.best_score_}')
# Out:
# Best parameters for rf: {'n_estimators': 100, 'min_samples_leaf': 10, 'max_depth': 20}
# Best score for rf: 0.8001390068731176
# Best parameters for gbc: {'n_estimators': 100, 'min_samples_leaf': 5, 'learning_rate': 0.2}
# Best score for gbc: 0.7972997678490656
# Best parameters for hgbc: {'min_samples_leaf': 2, 'max_iter': 100, 'max_depth': None}
# Best score for hgbc: 0.7923306661455223

# %%
def train(model,X_train,y_train,y_test):
    cross_validate(model, X_train, y_train, cv=5, scoring='accuracy')
    model.fit(X_train,y_train)
    score=model.score(X_test,y_test)
    print('Score of the model:', score)

# %%
rf=RandomForestClassifier(n_estimators=100, max_depth=10, min_samples_leaf=5)
train(rf, X_train, y_train, y_test)
# Out:
# Score of the model: 0.8034066713981547

# %%
gbc=GradientBoostingClassifier(n_estimators=200, learning_rate=0.1, min_samples_leaf=2)
train(gbc, X_train, y_train, y_test)
# Out:
# Score of the model: 0.7955997161107168

# %%
hgbc=HistGradientBoostingClassifier(max_iter=100, max_depth=5, min_samples_leaf=2)
train(hgbc, X_train, y_train, y_test)
# Out:
# Score of the model: 0.794889992902768

# %%
y_pred=rf.predict(X_test)
y_pred
# Out:
# array([0, 1, 0, ..., 0, 0, 0], shape=(1409,))

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
cm= confusion_matrix(y_test, y_pred)
print('Confusion Matrix:')
print(cm)
# Out:
# Confusion Matrix:
# [[935 100]
#  [177 197]]

# %%
print('Classification Report:')
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87      1035
#            1       0.66      0.53      0.59       374
#
#     accuracy                           0.80      1409
#    macro avg       0.75      0.72      0.73      1409
# weighted avg       0.79      0.80      0.80      1409
